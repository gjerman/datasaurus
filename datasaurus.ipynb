# %%
#https://simonwillison.net/2021/Nov/4/publish-open-source-python-library/

# %%
import pandas as pd
# %matplotlib inline

class Datasaurus():
    def __init__(self):
        self.data = pd.read_csv("data/DatasaurusDozen.tsv", sep='\t')
    
    @property
    def dataset_names(self):
        return list(self.data.dataset.unique())
    
    def plot(self, dataset_name):
        if dataset_name in self.dataset_names():
            fig = self.data.loc[self.data.dataset==dataset_name].plot.scatter(x="x", y="y")
            return fig
        else:
            raise ValueError(f"Invalid dataset name, avaible dataset are: {self.dataset_names}")
        
    def plot_all(self):
        pass
    
    def get_dataset(self,dataset_name):
        if dataset_name in self.dataset_names():
            return self.data.loc[self.data.dataset==dataset_name]
        else:
            raise ValueError(f"Invalid dataset name, avaible dataset are: {self.dataset_names}")
        
    @property
    def all_datasets(self):
        return self.data
    
    @property
    def summary_stats(self):
        pass

# %%
data = Datasaurus()

# %%
data.all_datasets
# Out:
#          dataset          x          y
# 0           dino  55.384600  97.179500
# 1           dino  51.538500  96.025600
# 2           dino  46.153800  94.487200
# 3           dino  42.820500  91.410300
# 4           dino  40.769200  88.333300
# ...          ...        ...        ...
# 1841  wide_lines  33.674442  26.090490
# 1842  wide_lines  75.627255  37.128752
# 1843  wide_lines  40.610125  89.136240
# 1844  wide_lines  39.114366  96.481751
# 1845  wide_lines  34.583829  89.588902
#
# [1846 rows x 3 columns]

# %%
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
dino = df.loc[df.dataset=="dino"]

# %%
dino.plot.scatter(x="x", y="y")
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
for dataset in df.dataset.unique():
    df.loc[df.dataset==dataset].plot.scatter(x="x", y="y")

# %%
for dataset in df.dataset.unique():
    data = df.loc[df.dataset==dataset]
    print(f"Dataset: {dataset}\n")
    print(data.describe().loc[["mean","std"]].round(decimals=3))
    print(f"Corr.{data.x.corr(data.y,method='pearson', min_periods=1).round(decimals=3)}")
    print("\n")
# Out:
# Dataset: dino
#
#            x       y
# mean  54.263  47.832
# std   16.765  26.935
# Corr.-0.064
#
#
# Dataset: away
#
#            x       y
# mean  54.266  47.835
# std   16.770  26.940
# Corr.-0.064
#
#
# Dataset: h_lines
#
#            x      y
# mean  54.261  47.83
# std   16.766  26.94
# Corr.-0.062
#
#
# Dataset: v_lines
#
#           x       y
# mean  54.27  47.837
# std   16.77  26.938
# Corr.-0.069
#
#
# Dataset: x_shape
#
#           x      y
# mean  54.26  47.84
# std   16.77  26.93
# Corr.-0.066
#
#
# Dataset: star
#
#            x      y
# mean  54.267  47.84
# std   16.769  26.93
# Corr.-0.063
#
#
# Dataset: high_lines
#
#            x       y
# mean  54.269  47.835
# std   16.767  26.940
# Corr.-0.069
#
#
# Dataset: dots
#
#            x      y
# mean  54.260  47.84
# std   16.768  26.93
# Corr.-0.06
#
#
# Dataset: circle
#
#            x       y
# mean  54.267  47.838
# std   16.760  26.930
# Corr.-0.068
#
#
# Dataset: bullseye
#
#            x       y
# mean  54.269  47.831
# std   16.769  26.936
# Corr.-0.069
#
#
# Dataset: slant_up
#
#            x       y
# mean  54.266  47.831
# std   16.769  26.939
# Corr.-0.069
#
#
# Dataset: slant_down
#
#            x       y
# mean  54.268  47.836
# std   16.767  26.936
# Corr.-0.069
#
#
# Dataset: wide_lines
#
#            x       y
# mean  54.267  47.832
# std   16.770  26.938
# Corr.-0.067

# %%
# Out:
#                 x           y
# count  142.000000  142.000000
# mean    54.266916   47.831602
# std     16.770000   26.937902

# %%
class Test():
    def __init__(self):
        self.data = "2"

# %%
a = Test()

# %%
data
# Out:
#          dataset          x          y
# 1704  wide_lines  65.815540  95.588374
# 1705  wide_lines  65.672265  91.933402
# 1706  wide_lines  39.002716  92.261838
# 1707  wide_lines  37.795303  93.532455
# 1708  wide_lines  35.513901  89.599190
# ...          ...        ...        ...
# 1841  wide_lines  33.674442  26.090490
# 1842  wide_lines  75.627255  37.128752
# 1843  wide_lines  40.610125  89.136240
# 1844  wide_lines  39.114366  96.481751
# 1845  wide_lines  34.583829  89.588902
#
# [142 rows x 3 columns]

# %%
df.pivot(columns="dataset", values=['x','y'])
# Out:
#            x                                                              \
# dataset away bullseye circle     dino dots h_lines high_lines slant_down
# 0        NaN      NaN    NaN  55.3846  NaN     NaN        NaN        NaN
# 1        NaN      NaN    NaN  51.5385  NaN     NaN        NaN        NaN
# 2        NaN      NaN    NaN  46.1538  NaN     NaN        NaN        NaN
# 3        NaN      NaN    NaN  42.8205  NaN     NaN        NaN        NaN
# 4        NaN      NaN    NaN  40.7692  NaN     NaN        NaN        NaN
# ...      ...      ...    ...      ...  ...     ...        ...        ...
# 1841     NaN      NaN    NaN      NaN  NaN     NaN        NaN        NaN
# 1842     NaN      NaN    NaN      NaN  NaN     NaN        NaN        NaN
# 1843     NaN      NaN    NaN      NaN  NaN     NaN        NaN        NaN
# 1844     NaN      NaN    NaN      NaN  NaN     NaN        NaN        NaN
# 1845     NaN      NaN    NaN      NaN  NaN     NaN        NaN        NaN
#
#                        ...        y                                     \
# dataset slant_up star  ...     dino dots h_lines high_lines slant_down
# 0            NaN  NaN  ...  97.1795  NaN     NaN        NaN        NaN
# 1            NaN  NaN  ...  96.0256  NaN     NaN        NaN        NaN
# 2            NaN  NaN  ...  94.4872  NaN     NaN        NaN        NaN
# 3            NaN  NaN  ...  91.4103  NaN     NaN        NaN        NaN
# 4            NaN  NaN  ...  88.3333  NaN     NaN        NaN        NaN
# ...          ...  ...  ...      ...  ...     ...        ...        ...
# 1841         NaN  NaN  ...      NaN  NaN     NaN        NaN        NaN
# 1842         NaN  NaN  ...      NaN  NaN     NaN        NaN        NaN
# 1843         NaN  NaN  ...      NaN  NaN     NaN        NaN        NaN
# 1844         NaN  NaN  ...      NaN  NaN     NaN        NaN        NaN
# 1845         NaN  NaN  ...      NaN  NaN     NaN        NaN        NaN
#
#
# dataset slant_up star v_lines wide_lines x_shape
# 0            NaN  NaN     NaN        NaN     NaN
# 1            NaN  NaN     NaN        NaN     NaN
# 2            NaN  NaN     NaN        NaN     NaN
# 3            NaN  NaN     NaN        NaN     NaN
# 4            NaN  NaN     NaN        NaN     NaN
# ...          ...  ...     ...        ...     ...
# 1841         NaN  NaN     NaN  26.090490     NaN
# 1842         NaN  NaN     NaN  37.128752     NaN
# 1843         NaN  NaN     NaN  89.136240     NaN
# 1844         NaN  NaN     NaN  96.481751     NaN
# 1845         NaN  NaN     NaN  89.588902     NaN
#
# [1846 rows x 26 columns]

# %%
from pandas.plotting import scatter_matrix



scatter_matrix(data.all_datasets, alpha=0.2, figsize=(6, 6), diagonal="kde");

# %%
data.all_datasets
# Out:
#          dataset          x          y
# 0           dino  55.384600  97.179500
# 1           dino  51.538500  96.025600
# 2           dino  46.153800  94.487200
# 3           dino  42.820500  91.410300
# 4           dino  40.769200  88.333300
# ...          ...        ...        ...
# 1841  wide_lines  33.674442  26.090490
# 1842  wide_lines  75.627255  37.128752
# 1843  wide_lines  40.610125  89.136240
# 1844  wide_lines  39.114366  96.481751
# 1845  wide_lines  34.583829  89.588902
#
# [1846 rows x 3 columns]
